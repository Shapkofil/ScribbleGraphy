# %%
import sys
import numpy as np
import pandas as pd
from scipy.misc import imread
import pickle
import os
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
import time

import tensorflow as tf
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model

from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.initializers import glorot_uniform

from keras.engine.topology import Layer
from keras.regularizers import l2
from keras import backend as K

from sklearn.utils import shuffle

import numpy.random as rng
import imageio
from skimage import io
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Please give below paths as per the paths in your system

# %%
train_folder = "D:\_BigFatProjects\ScribbleGraphy\Python\images_background\images_background"
val_folder = 'D:\_BigFatProjects\ScribbleGraphy\Python\images_evaluation\images_evaluation'
save_path = 'D:\_Python\JupyterProjects/data/'

# %%
def loadimgs(path,n = 0):
    '''
    path => Path of train directory or test directory
    '''
    X=[]
    y = []
    cat_dict = {}
    lang_dict = {}
    curr_y = n
    # we load every alphabet seperately so we can isolate them later
    for alphabet in os.listdir(path):
        print("loading alphabet: " + alphabet)
        lang_dict[alphabet] = [curr_y,None]
        alphabet_path = os.path.join(path,alphabet)
        # every letter/category has it's own column in the array, so  load seperately
        for letter in os.listdir(alphabet_path):
            cat_dict[curr_y] = (alphabet, letter)
            category_images=[]
            letter_path = os.path.join(alphabet_path, letter)
            # read all the images in the current category
            for filename in os.listdir(letter_path):
                image_path = os.path.join(letter_path, filename)
                image = imread(image_path,1)
                category_images.append(image)
                y.append(curr_y)
            try:
                X.append(np.stack(category_images))
            # edge case  - last one
            except ValueError as e:
                print(e)
                print("error - category_images:", category_images)
            curr_y += 1
            lang_dict[alphabet][1] = curr_y - 1
    y = np.vstack(y)
    X = np.stack(X)
    return X,y,lang_dict

# %% [markdown]
# ### Loading the train images into tensors

# %%
X,y,c=loadimgs(train_folder)
# Out:
# loading alphabet: Alphabet_of_the_Magi
# d:\_python\anaconda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# loading alphabet: Anglo-Saxon_Futhorc
# loading alphabet: Arcadian
# loading alphabet: Armenian
# loading alphabet: Asomtavruli_(Georgian)
# loading alphabet: Balinese
# loading alphabet: Bengali
# loading alphabet: Blackfoot_(Canadian_Aboriginal_Syllabics)
# loading alphabet: Braille
# loading alphabet: Burmese_(Myanmar)
# loading alphabet: Chinese
# loading alphabet: Cyrillic
# loading alphabet: Early_Aramaic
# loading alphabet: Futurama
# loading alphabet: Grantha
# loading alphabet: Greek
# loading alphabet: Gujarati
# loading alphabet: Hebrew
# loading alphabet: Inuktitut_(Canadian_Aboriginal_Syllabics)
# loading alphabet: Japanese_(hiragana)
# loading alphabet: Japanese_(katakana)
# loading alphabet: Korean
# loading alphabet: Latin
# loading alphabet: Malay_(Jawi_-_Arabic)
# loading alphabet: Mkhedruli_(Georgian)
# loading alphabet: N_Ko
# loading alphabet: Ojibwe_(Canadian_Aboriginal_Syllabics)
# loading alphabet: Sanskrit
# loading alphabet: Syriac_(Estrangelo)
# loading alphabet: Tagalog
# loading alphabet: Tifinagh

# %% [markdown]
# ### Saving the train tensors on disk

# %%
with open("pickles/train.pickle", "wb") as f:
    pickle.dump((X,c),f)

# %% [markdown]
# ### Loading the validation images into tensors

# %%
Xval,yval,cval=loadimgs(val_folder)
# Out:
# loading alphabet: Angelic
# d:\_python\anaconda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# loading alphabet: Atemayar_Qelisayer
# loading alphabet: Atlantean
# loading alphabet: Aurek-Besh
# loading alphabet: Avesta
# loading alphabet: Ge_ez
# loading alphabet: Glagolitic
# loading alphabet: Gurmukhi
# loading alphabet: Kannada
# loading alphabet: Keble
# loading alphabet: Malayalam
# loading alphabet: Manipuri
# loading alphabet: Mongolian
# loading alphabet: Old_Church_Slavonic_(Cyrillic)
# loading alphabet: Oriya
# loading alphabet: Sylheti
# loading alphabet: Syriac_(Serto)
# loading alphabet: Tengwar
# loading alphabet: Tibetan
# loading alphabet: ULOG

# %% [markdown]
# ### Saving the validation tensors on disk

# %%
with open("pickles/val.pickle", "wb") as f:
    pickle.dump((Xval,cval),f)

# %%
# del X, y ,c ,Xval, yval, cval

# %%
def initialize_weights(shape, name=None):
    return np.random.normal(loc = 0.0, scale = 1e-2, size = shape)

# %%
def initialize_bias(shape, name=None):
    return np.random.normal(loc = 0.5, scale = 1e-2, size = shape)

# %%
def get_siamese_model(input_shape):
    # Define the tensors for the two input images
    left_input = Input(input_shape)
    right_input = Input(input_shape)
    
    # Convolutional Neural Network
    model = Sequential()
    model.add(Conv2D(64, (10,10), activation='relu', input_shape=input_shape,
                   kernel_initializer=initialize_weights, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(128, (7,7), activation='relu',
                     kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(128, (4,4), activation='relu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(256, (4,4), activation='relu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(Flatten())
    model.add(Dense(4096, activation='sigmoid',
                   kernel_regularizer=l2(1e-3),
                   kernel_initializer=initialize_weights,bias_initializer=initialize_bias))
    
    # Generate the encodings (feature vectors) for the two images
    encoded_l = model(left_input)
    encoded_r = model(right_input)
    
    # Add a customized layer to compute the absolute difference between the encodings
    L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    L1_distance = L1_layer([encoded_l, encoded_r])
    
    # Add a dense layer with a sigmoid unit to generate the similarity score
    prediction = Dense(1,activation='sigmoid',bias_initializer=initialize_bias)(L1_distance)
    
    # Connect the inputs with the outputs
    siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)
    
    # return the model
    return siamese_net

# %%
model = get_siamese_model((105, 105, 1))
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 105, 105, 1)  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 105, 105, 1)  0
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 4096)         38947648    input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4096)         0           sequential_1[1][0]
#                                                                  sequential_1[2][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            4097        lambda_1[0][0]
# ==================================================================================================
# Total params: 38,951,745
# Trainable params: 38,951,745
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
optimizer = Adam(lr = 0.00006)
model.compile(loss="binary_crossentropy",optimizer=optimizer)

# %% [markdown]
# ### Loading the train tensors

# %%
with open("pickles/train.pickle", "rb") as f:
    (Xtrain, train_classes) = pickle.load(f)
    
print("Training alphabets: \n")
print(list(train_classes.keys()))
# Out:
# Training alphabets:
#
# ['Sanskrit', 'N_Ko', 'Arcadian', 'Ojibwe_(Canadian_Aboriginal_Syllabics)', 'Bengali', 'Burmese_(Myanmar)', 'Malay_(Jawi_-_Arabic)', 'Mkhedruli_(Georgian)', 'Syriac_(Estrangelo)', 'Early_Aramaic', 'Futurama', 'Armenian', 'Grantha', 'Alphabet_of_the_Magi', 'Korean', 'Hebrew', 'Tagalog', 'Greek', 'Japanese_(hiragana)', 'Japanese_(katakana)', 'Inuktitut_(Canadian_Aboriginal_Syllabics)', 'Anglo-Saxon_Futhorc', 'Blackfoot_(Canadian_Aboriginal_Syllabics)', 'Chinese', 'Asomtavruli_(Georgian)', 'Tifinagh', 'Latin', 'Cyrillic', 'Braille', 'Gujarati', 'Balinese']

# %%
with open("pickles/val.pickle", "rb") as f:
    (Xval, val_classes) = pickle.load(f)

print("Validation alphabets:", end="\n\n")
print(list(val_classes.keys()))
# Out:
# Validation alphabets:
#
# ['Angelic', 'Atlantean', 'Gurmukhi', 'Avesta', 'Kannada', 'Malayalam', 'Aurek-Besh', 'Mongolian', 'Atemayar_Qelisayer', 'Glagolitic', 'Tengwar', 'Keble', 'Oriya', 'Sylheti', 'Syriac_(Serto)', 'Manipuri', 'Ge_ez', 'ULOG', 'Tibetan', 'Old_Church_Slavonic_(Cyrillic)']

# %%
def get_batch(batch_size,s="train",language=None):
    """Create batch of n pairs, half same class, half different class"""
    if s == 'train':
        X = Xtrain
        categories = train_classes
    else:
        X = Xval
        categories = val_classes
    n_classes, n_examples, w, h = X.shape

    # randomly sample several classes to use in the batch
    if language is None:
        categories = rng.choice(n_classes,size=(batch_size,),replace=False)
    else:
        categories = rng.choice(np.arange(train_classes[language][0],train_classes[language][1]),size=(batch_size,))
    
    # initialize 2 empty arrays for the input image batch
    pairs=[np.zeros((batch_size, h, w,1)) for i in range(2)]
    
    # initialize vector for the targets
    targets=np.zeros((batch_size,))
    
    # make one half of it '1's, so 2nd half of batch has same class
    targets[batch_size//2:] = 1
    for i in range(batch_size):
        category = categories[i]
        idx_1 = rng.randint(0, n_examples)
        pairs[0][i,:,:,:] = X[category, idx_1].reshape(w, h, 1)
        idx_2 = rng.randint(0, n_examples)
        
        # pick images of same class for 1st half, different for 2nd
        if i >= batch_size // 2:
            category_2 = category  
        else: 
            # add a random number to the category modulo n classes to ensure 2nd image has a different category
            category_2 = (category + rng.randint(1,n_classes)) % n_classes
        
        pairs[1][i,:,:,:] = X[category_2,idx_2].reshape(w, h,1)
    
    return pairs, targets

# %%
def generate(batch_size, s="train"):
    """a generator for batches, so model.fit_generator can be used. """
    while True:
        pairs, targets = get_batch(batch_size,s)
        yield (pairs, targets)

# %%
def make_oneshot_task(N, s="val", language=None):
    """Create pairs of test image, support set for testing N way one-shot learning. """
    if s == 'train':
        X = Xtrain
        categories = train_classes
    else:
        X = Xval
        categories = val_classes
    n_classes, n_examples, w, h = X.shape
    
    indices = rng.randint(0, n_examples,size=(N,))
    if language is not None: # if language is specified, select characters for that language
        low, high = categories[language]
        if N > high - low:
            raise ValueError("This language ({}) has less than {} letters".format(language, N))
        categories = rng.choice(range(low,high),size=(N,),replace=False)

    else: # if no language specified just pick a bunch of random letters
        categories = rng.choice(range(n_classes),size=(N,),replace=False)            
    true_category = categories[0]
    ex1, ex2 = rng.choice(n_examples,replace=False,size=(2,))
    test_image = np.asarray([X[true_category,ex1,:,:]]*N).reshape(N, w, h,1)
    support_set = X[categories,indices,:,:]
    support_set[0,:,:] = X[true_category,ex2]
    support_set = support_set.reshape(N, w, h,1)
    targets = np.zeros((N,))
    targets[0] = 1
    targets, test_image, support_set = shuffle(targets, test_image, support_set)
    pairs = [test_image,support_set]

    return pairs, targets

# %%
def test_oneshot(model, N, k, s = "val", verbose = 0):
    """Test average N way oneshot learning accuracy of a siamese neural net over k one-shot tasks"""
    n_correct = 0
    if verbose:
        print("Evaluating model on {} random {} way one-shot learning tasks ... \n".format(k,N))
    for i in range(k):
        inputs, targets = make_oneshot_task(N,s)
        probs = model.predict(inputs)
        if np.argmax(probs) == np.argmax(targets):
            n_correct+=1
    percent_correct = (100.0 * n_correct / k)
    if verbose:
        print("Got an average of {}% {} way one-shot learning accuracy \n".format(percent_correct,N))
    return percent_correct

# %%
# Hyper parameters
evaluate_every = 200 # interval for evaluating on one-shot tasks
batch_size = 32
n_iter = 20000 # No. of training iterations
N_way = 20 # how many classes for testing one-shot tasks
n_val = 250 # how many one-shot tasks to validate on
best = -1

# %%
model_path = 'D:\_Python\JupyterProjects\Siamesemodel_chinese'

# %%
print("Starting training process!")
print("-------------------------------------")
t_start = time.time()
for i in range(1, n_iter+1):
    (inputs,targets) = get_batch(batch_size)
    loss = model.train_on_batch(inputs, targets)
    if i % evaluate_every == 0:
        print("\n ------------- \n")
        print("Time for {0} iterations: {1} mins".format(i, (time.time()-t_start)/60.0))
        print("Train Loss: {0}".format(loss)) 
        val_acc = test_oneshot(model, N_way, n_val, verbose=True)
        model.save_weights(os.path.join(model_path, 'weights.{}.h5'.format(i)))
        if val_acc >= best:
            print("Current best: {0}, previous best: {1}".format(val_acc, best))
            best = val_acc
# Out:
# Starting training process!
# -------------------------------------
#
#  -------------
#
# Time for 200 iterations: 2.91958087682724 mins
# Train Loss: 2.615919351577759
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 29.6% 20 way one-shot learning accuracy
#
# Current best: 29.6, previous best: -1
#
#  -------------
#
# Time for 400 iterations: 5.626948273181915 mins
# Train Loss: 1.8567231893539429
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 36.0% 20 way one-shot learning accuracy
#
# Current best: 36.0, previous best: 29.6
#
#  -------------
#
# Time for 600 iterations: 8.297924558321634 mins
# Train Loss: 1.4415265321731567
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 47.2% 20 way one-shot learning accuracy
#
# Current best: 47.2, previous best: 36.0
#
#  -------------
#
# Time for 800 iterations: 10.964477467536927 mins
# Train Loss: 1.0838751792907715
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 49.2% 20 way one-shot learning accuracy
#
# Current best: 49.2, previous best: 47.2
#
#  -------------
#
# Time for 1000 iterations: 13.627055565516153 mins
# Train Loss: 0.9302389025688171
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 46.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1200 iterations: 16.29742299715678 mins
# Train Loss: 0.8835141658782959
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 58.4% 20 way one-shot learning accuracy
#
# Current best: 58.4, previous best: 49.2
#
#  -------------
#
# Time for 1400 iterations: 18.957053387165068 mins
# Train Loss: 0.9332815408706665
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 59.2% 20 way one-shot learning accuracy
#
# Current best: 59.2, previous best: 58.4
#
#  -------------
#
# Time for 1600 iterations: 21.620097025235495 mins
# Train Loss: 0.7409846186637878
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 63.6% 20 way one-shot learning accuracy
#
# Current best: 63.6, previous best: 59.2
#
#  -------------
#
# Time for 1800 iterations: 24.285275189081826 mins
# Train Loss: 0.6467411518096924
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 65.2% 20 way one-shot learning accuracy
#
# Current best: 65.2, previous best: 63.6
#
#  -------------
#
# Time for 2000 iterations: 26.953472602367402 mins
# Train Loss: 0.5658894777297974
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 63.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 2200 iterations: 29.62442537943522 mins
# Train Loss: 0.547600507736206
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 57.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 2400 iterations: 32.30060734351476 mins
# Train Loss: 0.5376180410385132
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 67.6% 20 way one-shot learning accuracy
#
# Current best: 67.6, previous best: 65.2
#
#  -------------
#
# Time for 2600 iterations: 34.98183797597885 mins
# Train Loss: 0.5120387077331543
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 72.0% 20 way one-shot learning accuracy
#
# Current best: 72.0, previous best: 67.6
#
#  -------------
#
# Time for 2800 iterations: 37.66164129177729 mins
# Train Loss: 0.5274816155433655
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 67.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 3000 iterations: 40.31901132663091 mins
# Train Loss: 0.49812984466552734
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 64.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 3200 iterations: 42.996615473429365 mins
# Train Loss: 0.5031448006629944
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 67.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 3400 iterations: 45.67544566392898 mins
# Train Loss: 0.3465556502342224
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 71.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 3600 iterations: 48.341195452213285 mins
# Train Loss: 0.45714032649993896
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 68.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 3800 iterations: 51.01921013593674 mins
# Train Loss: 0.5388235449790955
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 68.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 4000 iterations: 53.697800497214 mins
# Train Loss: 0.4702201187610626
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 68.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 4200 iterations: 56.36817906697591 mins
# Train Loss: 0.3657073676586151
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 72.8% 20 way one-shot learning accuracy
#
# Current best: 72.8, previous best: 72.0
#
#  -------------
#
# Time for 4400 iterations: 59.04295324087143 mins
# Train Loss: 0.3514416217803955
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 75.2% 20 way one-shot learning accuracy
#
# Current best: 75.2, previous best: 72.8
#
#  -------------
#
# Time for 4600 iterations: 61.70200217564901 mins
# Train Loss: 0.3933544158935547
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 75.2% 20 way one-shot learning accuracy
#
# Current best: 75.2, previous best: 75.2
#
#  -------------
#
# Time for 4800 iterations: 64.36803394556046 mins
# Train Loss: 0.28616365790367126
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 69.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 5000 iterations: 67.03195502758027 mins
# Train Loss: 0.3699118494987488
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 66.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 5200 iterations: 69.68862974643707 mins
# Train Loss: 0.3351638913154602
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 72.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 5400 iterations: 72.35884341398875 mins
# Train Loss: 0.39889857172966003
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 74.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 5600 iterations: 75.03129938046138 mins
# Train Loss: 0.25536254048347473
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 77.2% 20 way one-shot learning accuracy
#
# Current best: 77.2, previous best: 75.2
#
#  -------------
#
# Time for 5800 iterations: 77.68760211865107 mins
# Train Loss: 0.24828065931797028
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 76.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 6000 iterations: 80.35919650793076 mins
# Train Loss: 0.3399219810962677
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 70.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 6200 iterations: 83.0157741745313 mins
# Train Loss: 0.21714672446250916
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 77.2% 20 way one-shot learning accuracy
#
# Current best: 77.2, previous best: 77.2
#
#  -------------
#
# Time for 6400 iterations: 85.6849903066953 mins
# Train Loss: 0.5594143867492676
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 74.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 6600 iterations: 88.35203751325608 mins
# Train Loss: 0.5991491079330444
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 75.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 6800 iterations: 91.00627708435059 mins
# Train Loss: 0.3158453702926636
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 77.2% 20 way one-shot learning accuracy
#
# Current best: 77.2, previous best: 77.2
#
#  -------------
#
# Time for 7000 iterations: 93.67918724616369 mins
# Train Loss: 0.27231788635253906
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 74.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 7200 iterations: 96.34785217841467 mins
# Train Loss: 0.3335610032081604
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 74.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 7400 iterations: 99.01030952135721 mins
# Train Loss: 0.18220975995063782
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 76.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 7600 iterations: 101.67599993944168 mins
# Train Loss: 0.3432808220386505
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 81.2% 20 way one-shot learning accuracy
#
# Current best: 81.2, previous best: 77.2
#
#  -------------
#
# Time for 7800 iterations: 104.33853839635849 mins
# Train Loss: 0.37048107385635376
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 74.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 8000 iterations: 106.99312513271967 mins
# Train Loss: 0.23067432641983032
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 71.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 8200 iterations: 109.66260853211085 mins
# Train Loss: 0.20392894744873047
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 79.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 8400 iterations: 112.31708818276724 mins
# Train Loss: 0.34396252036094666
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 78.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 8600 iterations: 114.97132428487141 mins
# Train Loss: 0.2098444104194641
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 71.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 8800 iterations: 117.6390990336736 mins
# Train Loss: 0.18708553910255432
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 76.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 9000 iterations: 120.30244797468185 mins
# Train Loss: 0.21420934796333313
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 76.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 9200 iterations: 122.97636010249455 mins
# Train Loss: 0.27618658542633057
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 77.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 9400 iterations: 125.64630434910457 mins
# Train Loss: 0.25931286811828613
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 72.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 9600 iterations: 128.30186240673066 mins
# Train Loss: 0.32682716846466064
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 78.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 9800 iterations: 130.96705085833867 mins
# Train Loss: 0.272744357585907
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 80.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 10000 iterations: 133.63112064997355 mins
# Train Loss: 0.19506029784679413
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 77.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 10200 iterations: 136.3027046918869 mins
# Train Loss: 0.1911230832338333
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 76.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 10400 iterations: 138.98158582051596 mins
# Train Loss: 0.1870037019252777
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 75.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 10600 iterations: 141.66241017182668 mins
# Train Loss: 0.23174460232257843
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 82.4% 20 way one-shot learning accuracy
#
# Current best: 82.4, previous best: 81.2
#
#  -------------
#
# Time for 10800 iterations: 144.33199777205786 mins
# Train Loss: 0.2158728837966919
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 74.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 11000 iterations: 147.00850367943445 mins
# Train Loss: 0.30091592669487
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 79.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 11200 iterations: 149.67914336919785 mins
# Train Loss: 0.26554444432258606
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 80.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 11400 iterations: 152.352643207709 mins
# Train Loss: 0.3033183813095093
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 83.6% 20 way one-shot learning accuracy
#
# Current best: 83.6, previous best: 82.4
#
#  -------------
#
# Time for 11600 iterations: 155.01744233767192 mins
# Train Loss: 0.19169916212558746
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 76.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 11800 iterations: 157.68216559489568 mins
# Train Loss: 0.2278253585100174
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 80.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 12000 iterations: 160.34028048117955 mins
# Train Loss: 0.1709335446357727
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 83.6% 20 way one-shot learning accuracy
#
# Current best: 83.6, previous best: 83.6
#
#  -------------
#
# Time for 12200 iterations: 163.00432872374853 mins
# Train Loss: 0.22691889107227325
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 81.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 12400 iterations: 165.66744385162988 mins
# Train Loss: 0.22010108828544617
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 79.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 12600 iterations: 168.32882154385248 mins
# Train Loss: 0.15581613779067993
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 79.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 12800 iterations: 170.99629012346267 mins
# Train Loss: 0.2451281100511551
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 81.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 13000 iterations: 173.66625401178996 mins
# Train Loss: 0.18412049114704132
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 84.0% 20 way one-shot learning accuracy
#
# Current best: 84.0, previous best: 83.6
#
#  -------------
#
# Time for 13200 iterations: 176.336849351724 mins
# Train Loss: 0.18411532044410706
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 77.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 13400 iterations: 179.00597325166066 mins
# Train Loss: 0.17591044306755066
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 80.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 13600 iterations: 181.6696608543396 mins
# Train Loss: 0.169765442609787
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 79.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 13800 iterations: 184.33604558706284 mins
# Train Loss: 0.17058615386486053
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 83.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 14000 iterations: 187.0060119986534 mins
# Train Loss: 0.16768380999565125
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 77.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 14200 iterations: 189.6610560377439 mins
# Train Loss: 0.162353515625
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 80.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 14400 iterations: 192.32741157213846 mins
# Train Loss: 0.17576655745506287
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 84.0% 20 way one-shot learning accuracy
#
# Current best: 84.0, previous best: 84.0
#
#  -------------
#
# Time for 14600 iterations: 194.99577484925587 mins
# Train Loss: 0.18566107749938965
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 76.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 14800 iterations: 197.6628941377004 mins
# Train Loss: 0.1685272604227066
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 82.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 15000 iterations: 200.3292176882426 mins
# Train Loss: 0.20495504140853882
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 79.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 15200 iterations: 202.9854609409968 mins
# Train Loss: 0.21008989214897156
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 81.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 15400 iterations: 205.64715452988943 mins
# Train Loss: 0.2688882052898407
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 83.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 15600 iterations: 208.31037248770397 mins
# Train Loss: 0.2778785228729248
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 82.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 15800 iterations: 210.97779630422593 mins
# Train Loss: 0.25952577590942383
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 75.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 16000 iterations: 213.64766702651977 mins
# Train Loss: 0.17910170555114746
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 80.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 16200 iterations: 216.31525266567866 mins
# Train Loss: 0.1693466454744339
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 81.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 16400 iterations: 218.971757320563 mins
# Train Loss: 0.1836213320493698
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 79.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 16600 iterations: 221.65225802262623 mins
# Train Loss: 0.22083157300949097
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 80.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 16800 iterations: 224.31952696243923 mins
# Train Loss: 0.24542269110679626
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 82.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 17000 iterations: 226.97630408207576 mins
# Train Loss: 0.19436247646808624
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 86.8% 20 way one-shot learning accuracy
#
# Current best: 86.8, previous best: 84.0
#
#  -------------
#
# Time for 17200 iterations: 229.6524597088496 mins
# Train Loss: 0.14931251108646393
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 83.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 17400 iterations: 232.3231970111529 mins
# Train Loss: 0.15340670943260193
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 79.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 17600 iterations: 234.97911298672358 mins
# Train Loss: 0.2552831768989563
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 81.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 17800 iterations: 237.6469059586525 mins
# Train Loss: 0.23785388469696045
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 80.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 18000 iterations: 240.316237727801 mins
# Train Loss: 0.1939249336719513
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 76.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 18200 iterations: 242.97648022174835 mins
# Train Loss: 0.16956260800361633
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 83.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 18400 iterations: 245.64615941047668 mins
# Train Loss: 0.225190669298172
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 84.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 18600 iterations: 248.32731055021287 mins
# Train Loss: 0.25453129410743713
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 81.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 18800 iterations: 250.98521344661714 mins
# Train Loss: 0.2342621386051178
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 85.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 19000 iterations: 253.6603285988172 mins
# Train Loss: 0.19032296538352966
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 83.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 19200 iterations: 256.3246679584185 mins
# Train Loss: 0.185578852891922
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 79.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 19400 iterations: 258.99259231885276 mins
# Train Loss: 0.1587211787700653
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 84.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 19600 iterations: 261.6520767490069 mins
# Train Loss: 0.1822732388973236
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 85.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 19800 iterations: 264.3190612514814 mins
# Train Loss: 0.15472030639648438
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 80.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 20000 iterations: 266.9794026931127 mins
# Train Loss: 0.1439698338508606
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 82.0% 20 way one-shot learning accuracy

# %%
# Save the model architecture
with open('oneshot_architecture.json', 'w') as f:
    f.write(model.to_json())

#Save optimal weights
model.save_weights('oneshot_weights.h5')

# %% [markdown]
# ### Load model weights

# %%
model.load_weights(os.path.join(model_path, "weights.20000.h5"))

# %%
categories = train_classes
n_classes, n_examples, w, h = X.shape

# randomly sample several classes to use in the batch
categories = rng.choice(np.arange(train_classes["Chinese"][0],train_classes["Chinese"][1]),size=(batch_size,))
categories
# Out:
# array([308, 317, 312, 320, 305, 319, 311, 306, 306, 304, 321, 305, 310,
#        322, 300, 314, 318, 318, 314, 308, 311, 305, 308, 323, 319, 311,
#        317, 308, 310, 323, 316, 307])

# %%
chindex = np.arange(train_classes["Chinese"][0],train_classes["Chinese"][1])
chindex
# Out:
# array([300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312,
#        313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325,
#        326, 327, 328])

# %%
plt.imshow(Xtrain[0][1])

# %%
plt.imshow(Xtrain[20,1,:,:],cmap = 'gray')

# %%
with open("lang_dic.pickle","rb")as f:
    img_dic = pickle.load(f)
    
     
    #img_dic = np.stack(img_dic)
    
def make_oneshot_pairs(current_image,language):
    N = len(img_dic[language])
    test_image = np.asarray([current_image]*N)
    test_image  = test_image.reshape(N, 105, 105,1)
    support_set = img_dic[language].reshape(N, 105, 105,1)
    pairs = [test_image,support_set]
    return pairs

input = make_oneshot_pairs(Xtrain[0,0,:,:],"Futurama") 
input
# Out:
# [array([[[[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          ...,
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]]],
#
#
#         [[[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          ...,
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]]],
#
#
#         [[[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          ...,
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]]],
#
#
#         ...,
#
#
#         [[[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          ...,
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]]],
#
#
#         [[[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          ...,
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]]],
#
#
#         [[[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          ...,
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]]]], dtype=float32), array([[[[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          ...,
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]]],
#
#
#         [[[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          ...,
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]]],
#
#
#         [[[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          ...,
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]]],
#
#
#         ...,
#
#
#         [[[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          ...,
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]]],
#
#
#         [[[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          ...,
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]]],
#
#
#         [[[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          ...,
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]],
#
#          [[255.],
#           [255.],
#           [255.],
#           ...,
#           [255.],
#           [255.],
#           [255.]]]], dtype=float32)]

# %%
predictions = model.predict( make_oneshot_pairs(Xtrain[chindex[9],5,:,:],"Chinese") )
pin = np.argmax(predictions)
print(pin)
acc = np.max(predictions)*100
print(round(acc,2))
plt.imshow(img_dic["Chinese"][pin],cmap = 'gray')
# Out:
# 19
# 98.15

# %%
indices = rng.randint(9, size=3)
indices
# Out:
# array([0, 8, 3])

# %%
support_set = Xtrain[0,indices,:,:]
plt.imshow(concat_images(support_set))

# %% [markdown]
# ### Testing

# %% [markdown]
# ### Baseline model based on Nearest Neighbors using Euclidean distance (L2 distance)

# %%
def nearest_neighbour_correct(pairs,targets):
    """returns 1 if nearest neighbour gets the correct answer for a one-shot task
        given by (pairs, targets)"""
    L2_distances = np.zeros_like(targets)
    for i in range(len(targets)):
        L2_distances[i] = np.sum(np.sqrt(pairs[0][i]**2 - pairs[1][i]**2))
    if np.argmin(L2_distances) == np.argmax(targets):
        return 1
    return 0

# %%
def test_nn_accuracy(N_ways,n_trials):
    """Returns accuracy of NN approach """
    print("Evaluating nearest neighbour on {} unique {} way one-shot learning tasks ...".format(n_trials,N_ways))

    n_right = 0
    
    for i in range(n_trials):
        pairs,targets = make_oneshot_task(N_ways,"val")
        correct = nearest_neighbour_correct(pairs,targets)
        n_right += correct
    return 100.0 * n_right / n_trials

# %%
ways = np.arange(1,20,2)
resume =  False
trials = 50

# %%
val_accs, train_accs,nn_accs = [], [], []
for N in ways:    
    val_accs.append(test_oneshot(model, N, trials, "val", verbose=True))
    train_accs.append(test_oneshot(model, N, trials, "train", verbose=True))
    nn_acc = test_nn_accuracy(N, trials)
    nn_accs.append(nn_acc)
    print ("NN Accuracy = ", nn_acc)
    print("---------------------------------------------------------------------------------------------------------------")

# %% [markdown]
# ### Save the accuracies on disk

# %%
with open(os.path.join(save_path,"accuracies.pickle"), "wb") as f:
    pickle.dump((val_accs,train_accs,nn_accs),f)

# %% [markdown]
# ### Load the accuracies from disk

# %%
with open(os.path.join(save_path, "accuracies.pickle"), "rb") as f:
    (val_accs, train_accs, nn_accs) = pickle.load(f)

# %% [markdown]
# ### Below two functions are used for visualizing test image and support set

# %%
def concat_images(X):
    """Concatenates a bunch of images into a big matrix for plotting purposes."""
    nc, h , w, _ = X.shape
    X = X.reshape(nc, h, w)
    n = np.ceil(np.sqrt(nc)).astype("int8")
    img = np.zeros((n*w,n*h))
    x = 0
    y = 0
    for example in range(nc):
        img[x*w:(x+1)*w,y*h:(y+1)*h] = X[example]
        y += 1
        if y >= n:
            y = 0
            x += 1
    return img

# %%
def plot_oneshot_task(pairs):
    fig,(ax1,ax2) = plt.subplots(nrows=1, ncols=2)
    ax1.matshow(pairs[0][0].reshape(105,105), cmap='gray')
    img = concat_images(pairs[1])
    ax1.get_yaxis().set_visible(False)
    ax1.get_xaxis().set_visible(False)
    ax2.matshow(img,cmap='gray')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %%
# Example of concat image visualization
pairs, targets = make_oneshot_task(16,"train","Sanskrit")
plot_oneshot_task(pairs)

# %% [markdown]
# ### Resuts

# %%
fig,ax = plt.subplots(1)
ax.plot(ways, val_accs, "m", label="Siamese(val set)")
ax.plot(ways, train_accs, "y", label="Siamese(train set)")
plt.plot(ways, nn_accs, label="Nearest neighbour")

ax.plot(ways, 100.0/ways, "g", label="Random guessing")
plt.xlabel("Number of possible classes in one-shot tasks")
plt.ylabel("% Accuracy")
plt.title("Omiglot One-Shot Learning Performance of a Siamese Network")
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
inputs,targets = make_oneshot_task(20, "val", 'Oriya')
plt.show()

plot_oneshot_task(inputs)
